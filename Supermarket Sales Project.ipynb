# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('C:\\Users\\KRISHJAI\\OneDrive - Capgemini\\Desktop\\Notes and Ref\\Dataset and database\\YT CS-12 (Supermarket Sales)\\supermarket_sales .csv',parse_dates=['Date'])

# %%
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %%
data.nunique()
# Out:
# Invoice ID                 1000
# Branch                        3
# City                          3
# Customer type                 2
# Gender                        2
# Product line                  6
# Unit price                  943
# Quantity                     10
# Tax 5%                      990
# Total                       990
# Date                         89
# Time                        506
# Payment                       3
# cogs                        990
# gross margin percentage       1
# gross income                990
# Rating                       61
# dtype: int64

# %% [markdown]
# Invoice id: Computer generated sales slip invoice identification number
# Branch: Branch of supercenter (3 branches are available identified by A, B and C).
# City: Location of supercenters
# Customer type: Type of customers, recorded by Members for customers using member card and Normal for without member card.
# Gender: Gender type of customer
# Product line: General item categorization groups Electronic accessories, Fashion accessories, Food and beverages, Health and beauty, Home and lifestyle, Sports and travel
# Unit price: Price of each product in
# Quantity: Number of products purchased by customer
# Tax: 5% tax fee for customer buying
# Total: Total price including tax
# Date: Date of purchase (Record available from January 2019 to March 2019)
# Time: Purchase time (10am to 9pm)
# Payment: Payment used by customer for purchase (3 methods are available — Cash, Credit card and Ewallet)
# COGS: Cost of goods sold
# Gross margin percentage: Gross margin percentage
# Gross income: Gross income
# Rating: Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)

# %% [markdown]
# # 1. Display Top 5 Rows of The Dataset

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# # 2. Display Last 5 Rows of The Dataset

# %%
data.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675 2019-01-29  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900 2019-03-02  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320 2019-02-09  13:22     Cash
# 998       65.82         1   3.2910    69.1110 2019-02-22  15:33     Cash
# 999       88.34         7  30.9190   649.2990 2019-02-18  13:28     Cash
#
# ...

# %% [markdown]
# # 3. Print Random 5 Rows From Our Dataset

# %%
data.sample(5)
# Out:
#       Invoice ID Branch      City Customer type  Gender         Product line  \
# 716  857-16-3520      A    Yangon        Member  Female  Fashion accessories
# 275  566-19-5475      B  Mandalay        Normal    Male  Fashion accessories
# 903  865-41-9075      A    Yangon        Normal    Male   Food and beverages
# 689  305-03-2383      A    Yangon        Normal  Female   Food and beverages
# 263  447-15-7839      A    Yangon        Member  Female    Sports and travel
#
#      Unit price  Quantity   Tax 5%     Total       Date   Time  Payment  \
# 716       71.46         7  25.0110  525.2310 2019-03-28  16:06  Ewallet
# 275       47.97         7  16.7895  352.5795 2019-01-07  20:52     Cash
# 903       11.53         7   4.0355   84.7455 2019-01-28  17:35     Cash
# 689       67.10         3  10.0650  211.3650 2019-02-15  10:36     Cash
# 263       22.24        10  11.1200  233.5200 2019-02-09  11:00     Cash
#
#        cogs  gross margin percentage  gross income  Rating
# ...

# %% [markdown]
# # 4. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
print(f'Number of rows: {data.shape[0]} \nNumber of columns: {data.shape[1]}')
# Out:
# Number of rows: 1000
# Number of columns: 17

# %% [markdown]
# # 5. Check For Null Values In The Dataset

# %%
data.isnull().any()
# Out:
# Invoice ID                 False
# Branch                     False
# City                       False
# Customer type              False
# Gender                     False
# Product line               False
# Unit price                 False
# Quantity                   False
# Tax 5%                     False
# Total                      False
# Date                       False
# Time                       False
# Payment                    False
# cogs                       False
# gross margin percentage    False
# gross income               False
# Rating                     False
# dtype: bool

# %% [markdown]
# # 6. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %% [markdown]
# # 7. Get Overall Statistics About The Dataset

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
data.describe(include='all',datetime_is_numeric=True)
# Out:
#          Invoice ID Branch    City Customer type  Gender         Product line  \
# count          1000   1000    1000          1000    1000                 1000
# unique         1000      3       3             2       2                    6
# top     750-67-8428      A  Yangon        Member  Female  Fashion accessories
# freq              1    340     340           501     501                  178
# mean            NaN    NaN     NaN           NaN     NaN                  NaN
# min             NaN    NaN     NaN           NaN     NaN                  NaN
# 25%             NaN    NaN     NaN           NaN     NaN                  NaN
# 50%             NaN    NaN     NaN           NaN     NaN                  NaN
# 75%             NaN    NaN     NaN           NaN     NaN                  NaN
# max             NaN    NaN     NaN           NaN     NaN                  NaN
# std             NaN    NaN     NaN           NaN     NaN                  NaN
#
# ...

# %% [markdown]
# # Univarient Analysis

# %% [markdown]
# # 8. Find Aggregate Sales Among Branches. (Categorical Column)

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
sns.countplot(x = data['Branch'])
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='count'>

# %%
data['Branch'].value_counts().plot(kind='pie',autopct='%1.2f%%')
# Out:
# <AxesSubplot:ylabel='Branch'>

# %% [markdown]
# # 9. Find The Most Popular Payment Method Used By Customers (Categorical Column)

# %%
data['Payment'].value_counts().plot(kind='pie',autopct='%1.2f%%')
# Out:
# <AxesSubplot:ylabel='Payment'>

# %%
sns.countplot(x=data['Payment'])
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='count'>

# %% [markdown]
# # 10. Find The Distribution of Customer Ratings. (Numerical Column)

# %%
sns.histplot(data['Rating'])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Count'>

# %% [markdown]
# # 11. Find The Distribution of Cost of Goods sold. (Numerical Column)

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
sns.histplot(data['cogs'],kde=True)
# Out:
# <AxesSubplot:xlabel='cogs', ylabel='Count'>

# %%
data['cogs'].skew()
# Out:
# 0.8925698049581418

# %%
sns.boxplot(x=data['cogs'])
# Out:
# <AxesSubplot:xlabel='cogs'>

# %% [markdown]
# # Bivariate Analysis / Multivariate Analysis

# %% [markdown]
# # 12. Does The Cost of Goods Sold Affect The Ratings That The Customers Provide? (Numerical - Numerical)

# %%
sns.barplot(x='Rating', y='cogs', data=data)
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='cogs'>

# %%
sns.scatterplot(data['cogs'],data['Rating'])
# Out:
# C:\Users\KRISHJAI\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cogs', ylabel='Rating'>

# %% [markdown]
# # 13. Does The Gross Income Affect The Ratings That The Customers Provide? (Numerical - Numerical)

# %%
sns.scatterplot(data['gross income'],data['Rating'])
# Out:
# C:\Users\KRISHJAI\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gross income', ylabel='Rating'>

# %% [markdown]
# # 14. Find The Most Profitable Branch As Per Gross Income. (Numerical - Categorical)

# %%
sns.barplot(x='Branch', y='gross income', data=data)
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='gross income'>

# %%
sns.barplot(x=data['Branch'], y=data['gross income'],hue=data['City'])
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='gross income'>

# %% [markdown]
# # 15. Is There Any Relationship Between Gender And Gross Income? (Numerical - Categorical)

# %%
sns.barplot(x='Gender',y='gross income',data=data)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='gross income'>

# %%
sns.boxplot(x='Gender',y='gross income',data=data)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='gross income'>

# %%
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
sns.boxplot(x='Gender',y='gross income',data=data,hue='Customer type')
ax.legend(loc=1)

# %% [markdown]
# # 16. Find The Product Line That Generates The Most Income. (Numerical - Categorical)

# %%
plt.figure(figsize=(15,7))
sns.barplot(x='Product line',y='gross income',data=data)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='gross income'>

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
sns.countplot(hue='Product line',x='gross income',data=data)
# Out:
# <AxesSubplot:xlabel='gross income', ylabel='count'>

# %%
plt.figure(figsize=(15,7))
sns.boxplot(x='Product line',y='gross income',data=data)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='gross income'>

# %% [markdown]
# # 17. Find The Highest Unit Price In The Product Line. (Numerical - Categorical)

# %%
plt.figure(figsize=(15,7))
sns.barplot(x='Product line', y='Unit price',data=data)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Unit price'>

# %% [markdown]
# # 18. Find Different Payment Methods Used By Customers Citywise.(Categorical -Categorical)

# %%
plt.figure(figsize=(15,7))
sns.countplot(x=data['City'],hue=data['Payment'])
# Out:
# <AxesSubplot:xlabel='City', ylabel='count'>

# %%
sns.heatmap(pd.crosstab(data['City'],data['Payment']))
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='City'>

# %% [markdown]
# # 19. Which Product Line Is Purchased In The Highest Quantity?

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
plt.figure(figsize=(15,7))
sns.barplot(x='Product line',y='Quantity', data = data)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Quantity'>

# %% [markdown]
# # 20. Display Daily Sales by Day of the Week

# %%
data['Date'].dt.dayofweek
# Out:
# 0      5
# 1      4
# 2      6
# 3      6
# 4      4
#       ..
# 995    1
# 996    5
# 997    5
# 998    4
# 999    0
# Name: Date, Length: 1000, dtype: int64

# %%
dw = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}
data['Day']=data['Date'].dt.dayofweek.map(dw)

# %%
sns.barplot(x=data['Date'].dt.dayofweek.map(dw),y=data['gross income'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='gross income'>

# %%
data['Day'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data.drop('Day',axis=1)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# # 21. What Will Be the Highest Months for Sales

# %%
data['Date'].dt.month
# Out:
# 0      1
# 1      3
# 2      3
# 3      1
# 4      2
#       ..
# 995    1
# 996    3
# 997    2
# 998    2
# 999    2
# Name: Date, Length: 1000, dtype: int64

# %%
dm = {1:'January',2:'Febuary',3:'March'}
data['month']=data['Date'].dt.month.map(dm)

# %%
sns.barplot(x=data['Date'].dt.month.map(dm),y=data['gross income'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='gross income'>

# %%
data['month'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['Time'] = pd.to_datetime(data['Time'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   datetime64[ns]
#  12  Payment                  1000 non-null   object
# ...

# %% [markdown]
# # 22. Visualize how hourly, monthly, branch wise and gender wise sales are affected

# %%
sns.relplot(x=data['Time'].dt.hour,  y = data['Quantity'], col= 'month' , row= 'Branch', kind="line", hue="Gender", style="Gender", data = data)

# %% [markdown]
# # 23. Sales by the hour in the comapny

# %%
sns.lineplot(x=data['Time'].dt.hour, y=data['Quantity']).set_title('Sales per hour')
# Out:
# Text(0.5, 1.0, 'Sales per hour')

# %%
sns.relplot(x=data['Time'].dt.hour, y=data['Quantity'], row=data['Day'], col=data['Date'].dt.month, kind='line', hue=data['Gender'])

# %% [markdown]
# # 24. check the relationship between customer type and rating

# %%
sns.barplot(x='Customer type', y='Rating', data=data)
# Out:
# <AxesSubplot:xlabel='Customer type', ylabel='Rating'>

# %% [markdown]
# # 25. customer types according to branch

# %%
sns.countplot(x="Customer type", hue = "Branch", data = data)
# Out:
# <AxesSubplot:xlabel='Customer type', ylabel='count'>

# %% [markdown]
# # 26. Relationship between customer type amd sales

# %%
sns.barplot(x="Customer type", y="gross income", estimator = sum, data=data)
# Out:
# <AxesSubplot:xlabel='Customer type', ylabel='gross income'>
